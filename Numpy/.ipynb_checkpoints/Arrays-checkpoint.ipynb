# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5,6])
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
l = [1,2,3,4,5]
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l = [1,2,"akash", True, 10.2]
l
# Out:
# [1, 2, 'akash', True, 10.2]

# %%
arr = np.array(l)
arr
# Out:
# array(['1', '2', 'akash', 'True', '10.2'], dtype='<U32')

# %%
arr = np.array([1,2,3.4,True])
arr
# Out:
# array([1. , 2. , 3.4, 1. ])

# %%
l = [[1,2,3], [4,5,6], [7,8,9]]
l
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix = np.array(l)
matrix
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [7, 8, 9]])
